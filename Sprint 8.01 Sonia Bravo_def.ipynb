# %% [markdown]
# Nivell 1 SPRINT 8 Exercici 1
#
# Realitza la connexió en Python amb el MySQL Workbench per a carregar tota la informació que tens en les taules.
#
# Realitzaràs una visualització per a cada exercici. Comenta el que et crida l'atenció de graficar aquesta variable, justifica l'elecció del gràfic i interpreta els resultats en funció de les teves dades.

# %%
pip install mysql-connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/11.9 MB 6.2 MB/s eta 0:00:02
#      ------- -------------------------------- 2.1/11.9 MB 6.0 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.1/11.9 MB 5.9 MB/s eta 0:00:02
#      -------------- ------------------------- 4.2/11.9 MB 5.6 MB/s eta 0:00:02
#      ------------------- -------------------- 5.8/11.9 MB 5.8 MB/s eta 0:00:02
#      ----------------------- ---------------- 6.8/11.9 MB 5.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 8.4/11.9 MB 5.9 MB/s eta 0:00:01
#      --------------------------------- ------ 10.0/11.9 MB 6.3 MB/s eta 0:00:01
#      -------------------------------------- - 11.5/11.9 MB 6.3 MB/s eta 0:00:01
#      ---------------------------------------- 11.9/11.9 MB 6.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
# ...

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/110.1 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/110.1 kB ? eta -:--:--
#      ---------- -------------------------- 30.7/110.1 kB 435.7 kB/s eta 0:00:01
#      ------------------------------ ------ 92.2/110.1 kB 871.5 kB/s eta 0:00:01
#      ------------------------------ ------ 92.2/110.1 kB 871.5 kB/s eta 0:00:01
#      ------------------------------------ 110.1/110.1 kB 530.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.9 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 816.8 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB 1.3 MB/s eta 0:00:07
#    ---------------------------------------- 0.1/8.1 MB 787.7 kB/s eta 0:00:11
# ...

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 660.6 kB/s eta 0:00:01
#    -------- ------------------------------ 61.4/294.9 kB 656.4 kB/s eta 0:00:01
#    -------------- ----------------------- 112.6/294.9 kB 819.2 kB/s eta 0:00:01
#    ---------------------- --------------- 174.1/294.9 kB 958.1 kB/s eta 0:00:01
#    ------------------------------ --------- 225.3/294.9 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.3 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.1/11.3 MB 1.1 MB/s eta 0:00:11
# ...

# %%
pip install pymysql
# Out:
# ...
#   Using cached PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Using cached PyMySQL-1.1.1-py3-none-any.whl (44 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cryptography
# Out:
# ...
#    ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#    --------- ------------------------------ 0.8/3.4 MB 6.2 MB/s eta 0:00:01
#    ------------------ --------------------- 1.6/3.4 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------ --- 3.1/3.4 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.4/3.4 MB 5.8 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
# ...

# %%
from sqlalchemy import text
from sqlalchemy import create_engine
import pandas as pd


engine = create_engine("mysql+pymysql://root:rootroot@localhost/transactions_3")  ##Creación del engine¿?##

with engine.connect() as conn:                                                     ##Obtener nombres de todas la tablas##
    tablas = conn.execute(text("SHOW TABLES")).fetchall()   


Trans3 = {}                                                                        ##Crear un dicc con un Dataframe por tabla##
for tabla in tablas:
    nombre = tabla[0]
    df = pd.read_sql(f"SELECT * FROM {nombre}", con=engine)
    Trans3[nombre] = df

print(Trans3['transactions'].head())
# Out:
#                                      id   card_id business_id  \
# 0  02C6201E-D90A-1859-B4EE-88D2986D3B02  CcU-2938      b-2362
# 1  0466A42E-47CF-8D24-FD01-C0B689713128  CcU-4219      b-2302
# 2  063FBA79-99EC-66FB-29F7-25726D1764A5  CcU-2987      b-2250
# 3  0668296C-CDB9-A883-76BC-2E4C44F8C8AE  CcU-3743      b-2618
# 4  06CD9AA5-9B42-D684-DDDD-A5E394FEBA99  CcU-2959      b-2346
#
#             timestamp  amount  declined product_ids  user_id      lat  \
# 0 2021-08-28 23:42:24  466.92         0     71,1,19       92  81.9185
# 1 2021-07-26 07:29:18   49.53         0    47,97,43      170 -43.9695
# 2 2022-01-06 21:25:27   92.61         0  47,67,31,5      275 -81.2227
# 3 2022-01-26 02:07:14  394.18         0    89,83,79      265 -34.3593
# 4 2021-10-26 23:00:01  279.93         0       43,31       92  33.7381
#
#    longitude
# 0   -12.5276
# 1  -117.5250
# 2  -129.0500
# 3  -100.5560
# 4   158.2980

# %% [markdown]
# Una variable numèrica.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
plt.figure(figsize=(8,5))

Tipospesos= Trans3['products']['weight']

Tipospesos.plot.hist(bins=25, color='darkblue', edgecolor='black', rwidth=0.9, alpha=0.7)

valores_peso = sorted(Tipospesos.unique())

plt.xticks(valores_peso, rotation=37)

plt.title('Cantidad de cada peso', fontsize=16)
plt.xlabel('Pesos distintos que hay', fontsize=12)
plt.ylabel('Recuento de pesos', fontsize=12)

plt.show() ##Sin ponerlo tb sale
# Out:
# Text(0, 0.5, 'Recuento de pesos')

# %% [markdown]
# En el gráfico anterior observamos que solamente se coge una variable, en este caso, elpeso de los productos. Vemos que hay doce distintos pesos, y que cada uno de ellos, se repite ocho  nueve veces (es decir, hay ocho o nueve productos con ese peso).

# %% [markdown]
# Dues variables numèriques.

# %%
## Dos numéricas con conexión

##plt.figure(figsize=(8,5))  ##El tamaño, pero lo quito pq sale <Figure size 800x500 with 0 Axes> antes del gráfico si no.

Tipospesos= Trans3['products']['weight']
Precios= Trans3['products']['price']

##fig, ax = plt.subplots() (Sin usar)
fig, ax = plt.subplots()
plt.scatter(Tipospesos, Precios, color='darkblue', alpha=0.6)


plt.xlabel('Pesos distintos que hay', fontsize=10)
plt.ylabel('Precios', fontsize=10)
plt.title('Precios por cada peso', fontsize=13)
##valores_peso = sorted(Tipospesos)
valores_peso = sorted(Tipospesos.unique())

plt.xticks(valores_peso, rotation=45)  # Rotar etiquetas si son largas

plt.tight_layout()  # Ajustar diseño
plt.show()

# %% [markdown]
# En el gráfico anterior observamos que se cogen dos variables, el peso de los productos y los precios de cada producto. Vemos que marca los distintos precios de cada ocho o nueve productos que tienen cada uno de los doce distintos pesos. No destaca ningún vínculo entre peso y precio, ya que hay productos caros que pesan tanto poco como medio o mucho, y productos baratos que también pueden pesar poco, medio o mucho.

# %% [markdown]
# Exercici Una variable categòrica.

# %%
plt.figure(figsize=(5,3))


##def add_value_label(x_list, y_list)
    ##for i in range(1, len(x_list) + 1):
        ##plt.text(i, y_list[i - 1], y_list[i - 1]) ##Intento 

Rechazados_o_no= Trans3['transactions']['declined'].value_counts()

Rechazados_o_no.plot.bar(color='darkblue', edgecolor='black', alpha=0.7)  ##plot(kind = 'bar', stacked = True) ##Stacked false o no poner es  no poner la leyenda.
##se usa para tres variables mínmo, aquí no hace nada


# Intento de agregar etiquetas de datos

##add_value_label(Rechazados_o_no)
##for i in enumerate(y):
#     plt.text(x[i], valor + 0.2, str(valor), ha='center', fontsize=10)

plt.title('Distribución de transacciones entre rechazadas o aceptadas', fontsize=16)
plt.xlabel('Aceptadas                     Rechazadas ', fontsize=12)
plt.xticks(rotation=360)
##plt.pyplot.text(x, y, s, fontdict=None, **kwargs)

##plt.tight_layout()  #Aquí se ajusta el diseño para evitar que se solapen (No sé excatamente...)
plt.show()

# %% [markdown]
# Se observa el total de transacciones distribuidas entre aceptadas y rechazadas, de las cuales las rechazadas no superan las 100, y las aceptadas casi llegan a 500. (Todavía no sé poner etiqueta de datos, por eso no las cifro exactamente).

# %% [markdown]
# - Exercici 4 Una variable categòrica i una numèrica.

# %%
##plt.figure(figsize=(5,3))

##def add_value_label(x_list, y_list):
    ##for i in range(1, len(x_list) + 1):
        ##plt.text(i, y_list[i - 1], y_list[i - 1])

Total=Trans3['transactions'].groupby("declined")[["amount"]].sum()

Total.plot.bar(color='darkblue', stacked = True)  ##plot(kind = 'bar', stacked = True)

##valores_rechzados = sorted(Rechazados_o_no)

# Agregar etiquetas de datos

##add_value_label(Rechazados_o_no, Ventas)
##for i in enumerate(y):
#     plt.text(x[i], valor + 0.2, str(valor), ha='center', fontsize=10)

plt.title('Total de ventas entre rechazadas o aceptadas', fontsize=13)
plt.xlabel('Rechazadas                                   Aceptadas', fontsize=11)
plt.xticks(rotation=360)
##plt.pyplot.text(x, y, s, fontdict=None, **kwargs)

##plt.tight_layout()  #Aquí se ajusta el diseño para evitar que se solapen (No sé excatamente...)
plt.show()

# %% [markdown]
# Se observa el total de ventas (las transacciones realizadas), distribuidas entre aceptadas y rechazadas.

# %%
##Pruebas##
Trans3['transactions'].groupby("declined")[["amount"]].sum()
# Out:
#              amount
# declined
# 0         129505.59
# 1          21198.16

# %%
##Pruebas##
Join_peso_declined= pd.merge(pd.merge(Trans3['transactions'],Trans3['transactions_products'], left_on= 'id', right_on= 'transaction_id'),
                             Trans3['products'],left_on= 'product_id', right_on= 'id')
Join_peso_declined.head(2)
# Out:
#                                    id_x   card_id business_id  \
# 0  02C6201E-D90A-1859-B4EE-88D2986D3B02  CcU-2938      b-2362
# 1  02C6201E-D90A-1859-B4EE-88D2986D3B02  CcU-2938      b-2362
#
#             timestamp  amount  declined product_ids  user_id      lat  \
# 0 2021-08-28 23:42:24  466.92         0     71,1,19       92  81.9185
# 1 2021-08-28 23:42:24  466.92         0     71,1,19       92  81.9185
#
#    longitude                        transaction_id  product_id  id_y  \
# 0   -12.5276  02C6201E-D90A-1859-B4EE-88D2986D3B02           1     1
# 1   -12.5276  02C6201E-D90A-1859-B4EE-88D2986D3B02          19    19
#
#        product_name   price   colour  weight warehouse_id
# 0  Direwolf Stannis  161.11  #7c7c7c     1.0         WH-4
# 1        dooku solo   60.33  #3f3f3f     0.6       WH--14

# %%
print(Trans3['transactions'])
# Out:
#                                        id   card_id business_id  \
# 0    02C6201E-D90A-1859-B4EE-88D2986D3B02  CcU-2938      b-2362
# 1    0466A42E-47CF-8D24-FD01-C0B689713128  CcU-4219      b-2302
# 2    063FBA79-99EC-66FB-29F7-25726D1764A5  CcU-2987      b-2250
# 3    0668296C-CDB9-A883-76BC-2E4C44F8C8AE  CcU-3743      b-2618
# 4    06CD9AA5-9B42-D684-DDDD-A5E394FEBA99  CcU-2959      b-2346
# ..                                    ...       ...         ...
# 582  FD2E8957-414B-BEEC-E9AD-59AA7A8A6290  CcU-3232      b-2390
# 583  FD89D51B-AE8D-77DC-E450-B8083FBD3187  CcU-3960      b-2494
# 584  FD9CBCCD-8E1E-8DA1-4606-7E3A6F3A5A65  CcU-4331      b-2302
# 585  FE809ED4-2DB6-55AC-C915-929516E4646B  CcU-4849      b-2302
# 586  FE96CE47-BD59-381C-4E18-E3CA3D44E8FF  CcU-2945      b-2226
#
#               timestamp  amount  declined product_ids  user_id       lat  \
# 0   2021-08-28 23:42:24  466.92         0     71,1,19       92  81.91850
# ...

# %% [markdown]
# Exercici 5  Dues variables categòriques.

# %%
Tot= pd.merge(Trans3['transactions'],Trans3['users'], left_on='user_id', right_on='id') 

pd.crosstab(Tot["country"],Tot['declined']).plot.bar(stacked = True, color=['darkblue','grey'])

plt.title('Total de ventas rechazadas o aceptadas por países', fontsize=13)
plt.xlabel('Países', fontsize=11)
plt.xticks(rotation=360)

plt.show()

# %% [markdown]
# Se observa el total de ventas (las transacciones realizadas), distribuidas entre aceptadas y rechazadas, de cada país de donde son los usuarios; solamente Canadá tiene rechazadas.

# %%
Tot= pd.merge(Trans3['transactions'],Trans3['users'], left_on='user_id', right_on='id') 
Tot.groupby("country")["user_id"].count().head(10)
# Out:
# country
# Canada            352
# United Kingdom     62
# United States     173
# Name: user_id, dtype: int64

# %%
Tot= pd.merge(Trans3['transactions'],Trans3['users'], left_on='user_id', right_on='id') 
Tot.groupby("country")["declined"].value_counts().head(10)
# Out:
# country         declined
# Canada          0           265
#                 1            87
# United Kingdom  0            62
# United States   0           173
# Name: count, dtype: int64

# %%
pd.merge(Trans3['transactions'],Trans3['users'], left_on='user_id', right_on='id').head(2)
# Out:
#                                    id_x   card_id business_id  \
# 0  02C6201E-D90A-1859-B4EE-88D2986D3B02  CcU-2938      b-2362
# 1  0466A42E-47CF-8D24-FD01-C0B689713128  CcU-4219      b-2302
#
#             timestamp  amount  declined product_ids  user_id      lat  \
# 0 2021-08-28 23:42:24  466.92         0     71,1,19       92  81.9185
# 1 2021-07-26 07:29:18   49.53         0    47,97,43      170 -43.9695
#
#    longitude  id_y     name   surname           phone  \
# 0   -12.5276    92     Lynn    Riddle  1-387-885-4057
# 1  -117.5250   170  William  Benjamin       0800 1111
#
#                        email  birth_date         country        city  \
# 0  vitae.aliquet@outlook.edu  1984-09-21   United States     Bozeman
# 1        porttitor@icloud.ca  1987-05-15  United Kingdom  Coldstream
#
#   postal_code                     address
# 0       61871  P.O. Box 712, 7907 Est St.
# 1     KY0 0DY       662-8112 Praesent Av.

# %% [markdown]
# - Exercici 6 Tres variables.

# %%
Trans3['transactions']['Año'] = Trans3['transactions']['timestamp'].dt.year

Tot= pd.merge(Trans3['transactions'],Trans3['users'], left_on='user_id', right_on='id') 

grouped = Tot.groupby(['country', 'Año'])['amount'].sum().reset_index()

Colores= { 2021: 'darkblue',2022: 'lightblue'}

grafico=sns.barplot(data=grouped, x='country', y='amount', hue='Año', palette= Colores, alpha=0.7)

for container in grafico.containers:
    grafico.bar_label(container, labels=[f'{int(bar.get_height()):,}'.replace(',', '.') for bar in container],label_type='edge')
# Punto de miles en el eje y

import matplotlib.ticker as mticker
grafico.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'.replace(',', '.')))

plt.title('Total de ventas por países y año', fontsize=13)
plt.xlabel('Países', fontsize=11)
plt.ylabel('Amount', fontsize=11)
plt.xticks(rotation=360)
plt.show()

# %% [markdown]
# Escojo extraer el año y hacer el total anual de ventas entre por país de usuario (¡OJO!, no he descartado las operaciones rechzadas, debo aprender el código de ello aún).

# %%
Tot= pd.merge(Trans3['transactions'],Trans3['users'], left_on='user_id', right_on='id') 
Tot.groupby("country")["amount"].sum().head(10)
# Out:
# country
# Canada            89252.90
# United Kingdom    15216.29
# United States     46234.56
# Name: amount, dtype: float64

# %%
# Creamos una nueva columna que contenga solo el año
Trans3['transactions']['año'] = Trans3['transactions']['timestamp'].dt.year

# Mostramos las columnas para verificar
Trans3['transactions']
# Out:
#                                        id   card_id business_id  \
# 0    02C6201E-D90A-1859-B4EE-88D2986D3B02  CcU-2938      b-2362
# 1    0466A42E-47CF-8D24-FD01-C0B689713128  CcU-4219      b-2302
# 2    063FBA79-99EC-66FB-29F7-25726D1764A5  CcU-2987      b-2250
# 3    0668296C-CDB9-A883-76BC-2E4C44F8C8AE  CcU-3743      b-2618
# 4    06CD9AA5-9B42-D684-DDDD-A5E394FEBA99  CcU-2959      b-2346
# ..                                    ...       ...         ...
# 582  FD2E8957-414B-BEEC-E9AD-59AA7A8A6290  CcU-3232      b-2390
# 583  FD89D51B-AE8D-77DC-E450-B8083FBD3187  CcU-3960      b-2494
# 584  FD9CBCCD-8E1E-8DA1-4606-7E3A6F3A5A65  CcU-4331      b-2302
# 585  FE809ED4-2DB6-55AC-C915-929516E4646B  CcU-4849      b-2302
# 586  FE96CE47-BD59-381C-4E18-E3CA3D44E8FF  CcU-2945      b-2226
#
#               timestamp  amount  declined product_ids  user_id       lat  \
# 0   2021-08-28 23:42:24  466.92         0     71,1,19       92  81.91850
# ...

# %% [markdown]
# - Exercici 7 Graficar un Pairplot.

# %%
Join= pd.merge(pd.merge(Trans3['transactions'],Trans3['transactions_products'], left_on='id', right_on='transaction_id'),
Trans3['products'],left_on='product_id', right_on='id')

Column_numricas= ['amount', 'price', 'weight']

Plotnum= Join[Column_numricas]

sns.pairplot(Plotnum)  ##hue='amount')

plt.show()

# %% [markdown]
# No he puesto operaciones matemáticas, entiendo que no se ponen en el pairplot. Aquí podemos observar en la diagonal, en los tres gráficos univariados de las tres variables numéricas de la base de datos: En las ventas no destaca más que la transacciones más bajas son las más repetidas; en el precio, que hay un precio medio y uno alto (no el más alto), que son los más frecuentes; y en peso, que solamente se han vendido seis de los doce pesos que hay.

# %%
Join[['price', 'amount']].corr()
# Out:
#            price    amount
# price   1.000000  0.011335
# amount  0.011335  1.000000

# %%
##Pruebas mías##
# 
Tiposprecios= Trans3['products']['price']
Ventas= Trans3['transactions']['amount']

fig, ax = plt.subplots()
plt.scatter(Ventas, Tiposprecios, color='darkblue')

plt.xlabel('Precios distintos que hay', fontsize=10)
plt.ylabel('Ventas', fontsize=10)
plt.title('Ventas por cada precio', fontsize=10)
##valores_peso = sorted(Tipospesos)
valores_precios = sorted(Tipospesos.unique())
plt.xticks(valores_precios, rotation=45)  # Rotar etiquetas si son largas
plt.tight_layout()  # Ajustar diseño para evitar solapamientos
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 5
#       2 Ventas= Trans3['transactions']['amount']
#       4 fig, ax = plt.subplots()
# ----> 5 plt.scatter(Ventas, Tiposprecios, color='darkblue')
#       8 plt.xlabel('Precios distintos que hay', fontsize=10)
#       9 plt.ylabel('Ventas', fontsize=10)
#
# File c:\Users\sbrav\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# ...
